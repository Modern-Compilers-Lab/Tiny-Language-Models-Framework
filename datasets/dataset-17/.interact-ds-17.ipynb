# %%
f = open('./data-ds-17/traced_snippets.txt', 'r')
traces = f.read().split('\n\n')

# %%
print(len(traces))
# Out:
# 6000001

# %%
print(traces[-2])
# Out:
# # code
# j = 122
# i = 10 * j
# b = 211
# c = 4
# u = 43
# x = u - j
# p = c / 153
# w = b + i
# while 1 < u:
# 	p = 237
# 	u = u / c
# print(x)
# #STEP
# # code
# @j = 122$|
# i = 10 * j
# b = 211
# c = 4
# u = 43
# x = u - j
# p = c / 153
# w = b + i
# while 1 < u:
# 	p = 237
# 	u = u / c
# print(x)
# #STEP
# # code
# j = 122
# @i = 10 * j$j?122|
# b = 211
# c = 4
# u = 43
# x = u - j
# p = c / 153
# w = b + i
# while 1 < u:
# 	p = 237
# 	u = u / c
# print(x)
# #STEP
# # code
# j = 122
# i = 10 * j
# @b = 211$j?122;i?1220|
# c = 4
# u = 43
# x = u - j
# p = c / 153
# w = b + i
# while 1 < u:
# 	p = 237
# 	u = u / c
# print(x)
# #STEP
# # code
# j = 122
# i = 10 * j
# b = 211
# @c = 4$j?122;i?1220;b?211|
# u = 43
# x = u - j
# p = c / 153
# w = b + i
# while 1 < u:
# 	p = 237
# 	u = u / c
# print(x)
# #STEP
# # code
# j = 122
# i = 10 * j
# b = 211
# c = 4
# @u = 43$j?122;i?1220;b?211;c?4|
# x = u - j
# p = c / 153
# w = b + i
# while 1 < u:
# 	p = 237
# 	u = u / c
# print(x)
# ...
